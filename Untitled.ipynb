# %% [markdown]
# Extracting Tesla Stock Data Using yfinance

# %% [markdown]
# # Import required libraries
# import yfinance as yf
# import pandas as pd
# import matplotlib.pyplot as plt
# from bs4 import BeautifulSoup
# import requests
#
# # Download Tesla stock data
# tesla_data = yf.Ticker("TSLA")
# tesla_stock = tesla_data.history(period="max")
#
# # Reset index to make the 'Date' column accessible
# tesla_stock.reset_index(inplace=True)
#
# # Display first few rows
# tesla_stock.head()

# %%
# Import required libraries
import yfinance as yf
import pandas as pd

# Use the Ticker function to create a ticker object for Tesla (TSLA)
tesla = yf.Ticker("TSLA")

# Extract stock data and save it in a DataFrame
tesla_data = tesla.history(period="max")

# Reset the index and display the first five rows
tesla_data.reset_index(inplace=True)
tesla_data.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Import required libraries
# ----> 2 import yfinance as yf
#       3 import pandas as pd
#       5 # Use the Ticker function to create a ticker object for Tesla (TSLA)
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
# Install required libraries
# !pip install pandas requests beautifulsoup4

# Import necessary libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Specify the URL for Tesla revenue data
url = 'https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue'

# Fetch the webpage content
html_data = requests.get(url).text

# Parse the HTML using BeautifulSoup
soup = BeautifulSoup(html_data, 'html.parser')

# Locate the revenue table based on specific class attributes
revenue_table = soup.find('table', attrs={'class': 'historical_data_table table'})

# Check if the table is found
if revenue_table is None:
    raise ValueError("Could not find the revenue table on the webpage.")

# Extract data from the table
rows = revenue_table.find_all('tr')
revenue_data = []

for row in rows[1:]:  # Skip the header row
    cols = row.find_all('td')
    if len(cols) > 1:  # Ensure valid rows with data
        date = cols[0].text.strip()
        revenue = cols[1].text.strip()
        revenue_data.append([date, revenue])

# Create a DataFrame
tesla_revenue = pd.DataFrame(revenue_data, columns=['Date', 'Revenue'])

# Clean the data
tesla_revenue['Revenue'] = tesla_revenue['Revenue'].replace({'\$': '', ',': ''}, regex=True).replace('', None).dropna().astype(float)

# Display the last five rows
print(tesla_revenue.tail())
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 23
#      21 # Check if the table is found
#      22 if revenue_table is None:
# ---> 23     raise ValueError("Could not find the revenue table on the webpage.")
#      25 # Extract data from the table
#      26 rows = revenue_table.find_all('tr')
#
# ValueError: Could not find the revenue table on the webpage.

# %%
# Install yfinance if not already installed
# !pip install yfinance

# Import the required library
import yfinance as yf

# Extract GameStop (GME) stock data
gme_data = yf.download('GME', start='2010-01-01', end='2025-01-01')

# Reset the index
gme_data.reset_index(inplace=True)

# Display the first five rows
print(gme_data.head())
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.2/948.2 kB 24.1 MB/s eta 0:00:00
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 109.7 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.17.8-cp312-cp312-linux_x86_64.whl size=303769 sha256=232827d29a21465ed895ef0b4517ea9d65e7d8ff8a14eb257959daf17de8dcbe
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/8f/65/34/456800445efeafb05164fe95285c70e81ba1d96bae30f43917
# Successfully built peewee
# ...
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                  GME       GME       GME       GME        GME
# 0      2010-01-04  3.854643  3.863059  3.703150  3.714933   26702800
# 1      2010-01-05  3.959004  3.996036  3.854643  3.856326   21269600
# ...

# %%
# Import necessary libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Specify the URL for GameStop revenue data
url = 'https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue'

# Add headers to simulate a browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Fetch the webpage content with headers
html_data = requests.get(url, headers=headers).text

# Parse the HTML using BeautifulSoup
soup = BeautifulSoup(html_data, 'html.parser')

# Locate the revenue table based on specific class attributes
tables = soup.find_all('table')
revenue_table = None

# Search for the correct table by checking its header or content
for table in tables:
    if "GameStop Quarterly Revenue" in table.text:
        revenue_table = table
        break

# Check if the table is found
if revenue_table is None:
    raise ValueError("Could not find the revenue table on the webpage.")

# Extract data from the table
rows = revenue_table.find_all('tr')
revenue_data = []

for row in rows[1:]:  # Skip the header row
    cols = row.find_all('td')
    if len(cols) > 1:  # Ensure valid rows with data
        date = cols[0].text.strip()
        revenue = cols[1].text.strip()
        revenue_data.append([date, revenue])

# Create a DataFrame
gme_revenue = pd.DataFrame(revenue_data, columns=['Date', 'Revenue'])

# Clean the data
gme_revenue['Revenue'] = gme_revenue['Revenue'].replace({'\$': '', ',': ''}, regex=True).replace('', None).dropna().astype(float)

# Display the last five rows
print(gme_revenue.tail())
# Out:
#           Date  Revenue
# 59  2010-01-31   3524.0
# 60  2009-10-31   1835.0
# 61  2009-07-31   1739.0
# 62  2009-04-30   1981.0
# 63  2009-01-31   3492.0

# %%
# Install matplotlib if not already installed
# !pip install matplotlib

# Import required libraries
import matplotlib.pyplot as plt
import yfinance as yf

# Define the make_graph function
def make_graph(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price', color='blue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price (USD)')
    plt.legend()
    plt.grid()
    plt.show()

# Fetch Tesla stock data
tesla_data = yf.download('TSLA', start='2010-01-01', end='2025-01-01')
tesla_data.reset_index(inplace=True)

# Plot the Tesla stock graph
make_graph(tesla_data, "Tesla Stock Price Over Time")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 150.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 140.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 99.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 155.2 MB/s eta 0:00:00
# ...
# [*********************100%***********************]  1 of 1 completed

# %%
# Install matplotlib if not already installed
# !pip install matplotlib

# Import required libraries
import matplotlib.pyplot as plt
import yfinance as yf

# Define the make_graph function
def make_graph(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price', color='blue')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Close Price (USD)')
    plt.legend()
    plt.grid()
    plt.show()

# Fetch GameStop stock data
gme_data = yf.download('GME', start='2010-01-01', end='2025-01-01')
gme_data.reset_index(inplace=True)

# Plot the GameStop stock graph
make_graph(gme_data, "GameStop Stock Price Over Time")
# Out:
# ...
# [*********************100%***********************]  1 of 1 completed
